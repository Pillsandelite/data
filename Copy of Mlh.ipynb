# %%
import pandas as pd

# %%
from google.colab import files
Uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4969678-0a1f-44d4-809b-c9f30187649f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4969678-0a1f-44d4-809b-c9f30187649f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FoodBalanceSheets_E_Africa_NOFLAG.csv to FoodBalanceSheets_E_Africa_NOFLAG (1).csv

# %%
url='https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning'
food_data = pd.read_csv(url, error_bad_lines=False)
food_data.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
food_data.isnull().sum()
# Out:
# <!DOCTYPE html>    0
# dtype: int64

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git config --global user.email 'ezeadannalyn@gmail.com'

# %%
# !git config --global user.name 'pillsandelite'

# %%
# !git add
# Out:
# Nothing specified, nothing added.
# Maybe you wanted to say 'git add .'?

# %%
# !git add './data/mlh.ipynb'
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "Colab Commit"
# Out:
# On branch master
#
# Initial commit
#
# Untracked files:
# 	.config/
# 	FoodBalanceSheets_E_Africa_NOFLAG (1).csv
# 	FoodBalanceSheets_E_Africa_NOFLAG.csv
# 	sample_data/
#
# nothing added to commit but untracked files present

# %%
# !git remote add origin https://ezeadannalyn@gmail.com:jara_app@github.com/pillsandelite/data.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ezeadannalyn@gmail.com:feathers@5@github.com/pillsandelite/data.git'

# %%
# !git push -u origin master --force
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ezeadannalyn@gmail.com:feathers@5@github.com/pillsandelite/data.git'

# %%
# !git remote rm origin
# Out:
# fatal: No such remote: origin

# %%
# !git remote add origin https://pillsandelite:jara_app@github.com/pillsandelite/data.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ezeadannalyn@gmail.com:jara_app@github.com/pillsandelite/data.git'

# %%
# !git push -u origin master --force
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://ezeadannalyn@gmail.com:jara_app@github.com/pillsandelite/data.git'

# %%
# !git remote rm origin
# Out:
# fatal: No such remote: origin

# %%
# !git remote add origin https://pillsandelite:jara_app@github.com/pillsandelite/hello.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://pillsandelite:jara_app@github.com/pillsandelite/data.git'
